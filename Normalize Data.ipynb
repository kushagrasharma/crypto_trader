# %%
import pandas as pd
import numpy as np

# %%
file_name = "15min_manyFeatures.csv"
df = pd.read_csv(file_name, parse_dates=True) 
df
# Out:
#        Unnamed: 0  Unnamed: 0.1            timestamp     high      low  \
# 0               0             0  2014-12-01 00:33:00   300.00   300.00
# 1               1             1  2014-12-01 00:48:00   300.00   300.00
# 2               2             2  2014-12-01 01:03:00   300.00   300.00
# 3               3             3  2014-12-01 01:18:00   370.00   300.00
# 4               4             4  2014-12-01 01:33:00   370.00   370.00
# 5               5             5  2014-12-01 01:48:00   370.00   370.00
# 6               6             6  2014-12-01 02:03:00   370.00   370.00
# 7               7             7  2014-12-01 02:18:00   370.00   370.00
# 8               8             8  2014-12-01 02:33:00   370.00   370.00
# 9               9             9  2014-12-01 02:48:00   370.00   370.00
# 10             10            10  2014-12-01 03:03:00   370.00   370.00
# 11             11            11  2014-12-01 03:18:00   370.00   370.00
# ...

# %%
df = df.drop(columns=["Unnamed: 0", "Unnamed: 0.1"])

# %%
df.columns
# Out:
# Index([u'timestamp', u'high', u'low', u'close', u'open', u'volume_btc',
#        u'volume_currency', u'willr4Hours', u'willr4Days', u'willrWeek',
#        u'tema4Hours', u'tema4Days', u'temaWeek', u'dema4Hours', u'dema4Days',
#        u'demaWeek', u'trueRange4Hours', u'trueRange4Days', u'trueRangeWeek',
#        u'linearRegSlope4Hours', u'linearRegSlope4Days', u'linearRegSlopeWeek',
#        u'std4Hours', u'tsf4Hours', u'tsf4Days', u'tsfWeek', u'rsi4Hours',
#        u'rsi4Days', u'rsiWeek', u'weighted_price'],
#       dtype='object')

# %%
features_to_normalize = ['willr4Hours', 'willr4Days', 'willrWeek', 'tema4Hours', 'tema4Days', 'temaWeek', 'dema4Hours', 
                         'dema4Days', 'demaWeek', 'trueRange4Hours', 'trueRange4Days', 'trueRangeWeek',
                         'linearRegSlope4Hours', 'linearRegSlope4Days', 'linearRegSlopeWeek',
                         'std4Hours', 'tsf4Hours', 'tsf4Days', 'tsfWeek', 'rsi4Hours',
                         'rsi4Days', 'rsiWeek',]
