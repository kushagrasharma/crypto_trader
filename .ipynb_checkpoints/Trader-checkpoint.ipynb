# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import time
from talib.abstract import *
def dateparse (time_in_secs):    
    return datetime.datetime.fromtimestamp(float(time_in_secs))

# %%
df = pd.read_csv('15min_fulldata.csv', parse_dates=True)
df.drop(labels="Unnamed: 0", axis=1, inplace=True)
df
# Out:
#             timestamp     high      low    close     open  volume_btc  \
# 0        12/1/14 0:33   300.00   300.00   300.00   300.00    0.150000
# 1        12/1/14 0:48   300.00   300.00   300.00   300.00    0.150000
# 2        12/1/14 1:03   300.00   300.00   300.00   300.00    0.150000
# 3        12/1/14 1:18   370.00   300.00   370.00   300.00    0.150000
# 4        12/1/14 1:33   370.00   370.00   370.00   370.00    0.150000
# 5        12/1/14 1:48   370.00   370.00   370.00   370.00    0.365222
# 6        12/1/14 2:03   370.00   370.00   370.00   370.00    0.398333
# 7        12/1/14 2:18   370.00   370.00   370.00   370.00    0.398333
# 8        12/1/14 2:33   370.00   370.00   370.00   370.00    0.398333
# 9        12/1/14 2:48   370.00   370.00   370.00   370.00    0.398333
# 10       12/1/14 3:03   370.00   370.00   370.00   370.00    0.398333
# 11       12/1/14 3:18   370.00   370.00   370.00   370.00    0.398333
# ...

# %%
df['std'] = (df['std'] - df['std'].mean()) / (df['std'].max() - df['std'].min())

# %%
df
# Out:
#             timestamp      high       low     close      open  volume_btc  \
# 0        12/1/14 0:33 -0.118012 -0.114753 -0.117187 -0.117222   -0.011795
# 1        12/1/14 0:48 -0.118012 -0.114753 -0.117187 -0.117222   -0.011795
# 2        12/1/14 1:03 -0.118012 -0.114753 -0.117187 -0.117222   -0.011795
# 3        12/1/14 1:18 -0.105768 -0.114753 -0.104992 -0.117222   -0.011795
# 4        12/1/14 1:33 -0.105768 -0.102766 -0.104992 -0.105023   -0.011795
# 5        12/1/14 1:48 -0.105768 -0.102766 -0.104992 -0.105023   -0.011768
# 6        12/1/14 2:03 -0.105768 -0.102766 -0.104992 -0.105023   -0.011764
# 7        12/1/14 2:18 -0.105768 -0.102766 -0.104992 -0.105023   -0.011764
# 8        12/1/14 2:33 -0.105768 -0.102766 -0.104992 -0.105023   -0.011764
# 9        12/1/14 2:48 -0.105768 -0.102766 -0.104992 -0.105023   -0.011764
# 10       12/1/14 3:03 -0.105768 -0.102766 -0.104992 -0.105023   -0.011764
# 11       12/1/14 3:18 -0.105768 -0.102766 -0.104992 -0.105023   -0.011764
# ...

# %%
def aggregate(df):
    df.sort_values('timestamp')
    agged = {'timestamp' : df.iloc[0].timestamp, 
             'high' : np.max(df.high),
             'low' : np.min(df.low),
             'close' : df.iloc[-1].close,
             'open' : df.iloc[0].open,
             'volume_btc' : np.sum(df.volume_btc),
             'volume_currency' : np.sum(df.volume_currency)}
    agged['weighted_price'] = np.mean([agged['high'], agged['low'], agged['close'], agged['open']])
    return pd.DataFrame(agged, index=[0], columns=['timestamp', 'high', 'low', 'close', 'open', 'volume_btc', 'volume_currency'])

# %%
i = 0
td = datetime.timedelta(minutes=15)
frames = []
df.sort_values('timestamp', inplace=True)
while i < len(df):
    j = i + 1
    while j < len(df):
        if df.iloc[j].timestamp > df.iloc[i].timestamp and df.iloc[j].timestamp < df.iloc[i].timestamp + td:
            j += 1
        else:
            break
    if j - i == 15:
        frames.append(df.iloc[i:j])
    i = j

# %%
aggregated_df = pd.concat([aggregate(x) for x in frames])
aggregated_df.reset_index(level=0, inplace=True)
del aggregated_df['index']

# %%
pasts = []
def RSI_self(i, window_length=14):
    if not pasts:
        for j in range(window_length, 0, -1):
            if i - (j * 1440) < 0:
                print(i)
            pasts.append(df.iloc[i - (j * 1440)].close)
    else:
        pasts.pop(0)
        pasts.append(df.iloc[i].close)
    return RSI(pd.DataFrame(pasts, index=np.arange(len(pasts)), columns=['close'])).iloc[-1]
    #pasts.append(df.iloc[i].close)
    delta = pd.Series(pasts).diff() 
    delta = delta[1:]
    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0
    roll_up1 = pd.stats.moments.ewma(up, window_length)
    roll_down1 = pd.stats.moments.ewma(down.abs(), window_length)
    RS1 = roll_up1 / roll_down1
    return (100.0 - (100.0 / (1.0 + RS1))).iloc[-1]

# %%
rsi = []
t1 = time.time()
for i in range(0, len(df)):
    if i % 10000 == 0:
        print(i)
        print(time.time()-t1)
        t1 = time.time()
    if i < 20160:
        rsi.append(0)
    else:
        rsi.append(RSI_self(i))
# Out:
# 0
# 0.0008399486541748047
# 10000
# 0.004713296890258789
# 20000
# 0.004871845245361328
# 30000
# 6.345288038253784
# 40000
# 6.066490173339844
# 50000
# 6.473586082458496
# 60000
# 7.002962350845337
# 70000
# 6.764132022857666
# 80000
# 6.262277126312256
# 90000
# 5.403566837310791
# 100000
# 5.40077018737793
# 110000
# 5.3499791622161865
# 120000
# 5.796144962310791
# 130000
# 5.330888986587524
# 140000
# 5.416859149932861
# 150000
# 6.221277952194214
# 160000
# 5.498335838317871
# 170000
# 5.481149911880493
# 180000
# 7.0258870124816895
# 190000
# 5.680816173553467
# 200000
# 6.029283761978149
# 210000
# 5.725904703140259
# 220000
# 5.404473066329956
# 230000
# 5.684697151184082
# 240000
# 5.3788158893585205
# 250000
# 5.739253997802734
# 260000
# 5.417478799819946
# 270000
# 5.3656651973724365
# 280000
# 5.631860017776489
# 290000
# 5.524579048156738
# 300000
# 5.383358955383301
# 310000
# 6.2039289474487305
# 320000
# 7.366654872894287
# 330000
# 5.892575979232788
# 340000
# ...

# %%
RSI(df, timeperiod=14)
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14       100.000000
# 15       100.000000
# 16       100.000000
# 17       100.000000
# 18       100.000000
# 19       100.000000
# 20       100.000000
# 21       100.000000
# 22       100.000000
# 23       100.000000
# 24       100.000000
# 25       100.000000
# 26       100.000000
# 27       100.000000
# 28       100.000000
# 29       100.000000
#             ...
# 97221     50.884901
# 97222     49.151713
# 97223     49.065782
# 97224     43.811786
# 97225     45.966683
# 97226     49.030141
# 97227     46.662500
# 97228     44.289610
# 97229     47.999200
# 97230     49.438775
# 97231     47.739757
# 97232     45.606391
# 97233     38.555151
# 97234     40.239578
# ...

# %%
df['rsi'] = RSI(df, timeperiod=14)

# %%
df.to_csv("15min_data.csv")

# %%
ndf = pd.read_csv('15min_features.csv', parse_dates=True)
#df.drop(labels="Unnamed: 0", axis=1, inplace=True)
df.merge(ndf, left_index=True, right_index=True).to_csv('15min_fulldata.csv')

# %%
df.merge(ndf, left_index=True, right_index=True)
# Out:
#                  timestamp     high      low    close     open  volume_btc  \
# 0      2014-12-01 00:33:00   300.00   300.00   300.00   300.00    0.150000
# 1      2014-12-01 00:48:00   300.00   300.00   300.00   300.00    0.150000
# 2      2014-12-01 01:03:00   300.00   300.00   300.00   300.00    0.150000
# 3      2014-12-01 01:18:00   370.00   300.00   370.00   300.00    0.150000
# 4      2014-12-01 01:33:00   370.00   370.00   370.00   370.00    0.150000
# 5      2014-12-01 01:48:00   370.00   370.00   370.00   370.00    0.365222
# 6      2014-12-01 02:03:00   370.00   370.00   370.00   370.00    0.398333
# 7      2014-12-01 02:18:00   370.00   370.00   370.00   370.00    0.398333
# 8      2014-12-01 02:33:00   370.00   370.00   370.00   370.00    0.398333
# 9      2014-12-01 02:48:00   370.00   370.00   370.00   370.00    0.398333
# 10     2014-12-01 03:03:00   370.00   370.00   370.00   370.00    0.398333
# ...
