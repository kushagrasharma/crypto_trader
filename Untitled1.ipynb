# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_csv("15min_fulldata.csv")

# %%
df
# Out:
#        index            timestamp     high      low    close     open  \
# 0          0  2014-12-01 00:33:00   300.00   300.00   300.00   300.00
# 1          1  2014-12-01 00:48:00   300.00   300.00   300.00   300.00
# 2          2  2014-12-01 01:03:00   300.00   300.00   300.00   300.00
# 3          3  2014-12-01 01:18:00   370.00   300.00   370.00   300.00
# 4          4  2014-12-01 01:33:00   370.00   370.00   370.00   370.00
# 5          5  2014-12-01 01:48:00   370.00   370.00   370.00   370.00
# 6          6  2014-12-01 02:03:00   370.00   370.00   370.00   370.00
# 7          7  2014-12-01 02:18:00   370.00   370.00   370.00   370.00
# 8          8  2014-12-01 02:33:00   370.00   370.00   370.00   370.00
# 9          9  2014-12-01 02:48:00   370.00   370.00   370.00   370.00
# 10        10  2014-12-01 03:03:00   370.00   370.00   370.00   370.00
# 11        11  2014-12-01 03:18:00   370.00   370.00   370.00   370.00
# ...

# %%
df.plot(x="index", y="weighted_price")

# %%
plt.show()

# %%
with open("test_history.log", "r") as f:
    history = pickle.load(f)

# %%
history[-1]
# Out:
# ['hold', 0, 10000.0]

# %%
with open("weights.txt") as f:
    weights = pickle.load(f)

# %%
weights
# Out:
# array([ nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan])
